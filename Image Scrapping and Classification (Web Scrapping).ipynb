# %% [markdown]
# # Image Scrapping and Classification (Web Scrapping)

# %%
#importing all the required libraries
import selenium
import pandas as pd
from selenium import webdriver # Importing selenium webdriver
import time

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#creating empty lists
Sarees_Image=[]
Trousers_Image=[]
Jeans_Image=[]

# %%
url1='https://www.amazon.in/'

# %%
driver_1 = webdriver.Edge("msedgedriver.exe")
driver_1.get(url1)

# searching required fields
search_bar = driver_1.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
search_bar.send_keys('sarees')

search_button = driver_1.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')  # Locating search_button by xpath
search_button.click()


start_page = 0
end_page = 10
for i in range(start_page,end_page+1):
    sar=driver_1.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']/img")
    for j in sar:
        image=j.get_attribute('src')
        Sarees_Image.append(image)
    try:
        nxt_button=driver_1.find_element_by_xpath("//li[@class='a-last']/a").click()
    except NoSuchElementException:
    #driver_1.get(nxt_button[i].get_attribute('href'))
        time.sleep(15)

# %%
Sarees_Image
# Out:
# ['https://m.media-amazon.com/images/I/71l3Vr-LNwL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91JYyTKEnYL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81zWhoRx35L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81RPtZiyogL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91WCQ88UV5L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91GKFgnS5uL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/810bWMiAmaL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91K7kfay53L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81j-y-KWb6L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91NhFxRQe7L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71SUNh9g6bL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91ecd4QxIdS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91UN3kCM5HL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/A1Sf5RQ1NoL._AC_UL320_.jpg',
# ...

# %%
len(Sarees_Image)
# Out:
# 880

# %%
driver_2 = webdriver.Edge("msedgedriver.exe")
driver_2.get(url1)

# searching required fields
search_bar = driver_2.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
search_bar.send_keys('trousers for men')

search_button = driver_2.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
search_button.click()


start_page = 0
end_page = 10
for i in range(start_page,end_page+1):
    sar=driver_2.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']/img")
    for j in sar:
        image=j.get_attribute('src')
        Trousers_Image.append(image)
        
    try:
        nxt_button=driver_2.find_element_by_xpath("//li[@class='a-last']/a").click()
    except NoSuchElementException:
    #driver_1.get(nxt_button[i].get_attribute('href'))
        time.sleep(15)

# %%
Trousers_Image
# Out:
# ['https://m.media-amazon.com/images/I/51FOUH5+inS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71mC5INUWBS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51t7sNlvhAL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71KonjbfARL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81-9O33VgBL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71mFpqsS0hL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71zLO45349L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61Djgl8NSSL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71Ns8ha1WRL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71lUwWedSQS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71UMSu5e6rL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71TCZqBVvWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81EPvT+9GcL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71UHoQ2wPzL._AC_UL320_.jpg',
# ...

# %%
len(Trousers_Image)
# Out:
# 376

# %%
driver_3 = webdriver.Edge("msedgedriver.exe")
driver_3.get(url1)

# searching required fields
search_bar = driver_3.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
search_bar.send_keys('jeans for men')

search_button = driver_3.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
search_button.click()


start_page = 0
end_page = 10
for i in range(start_page,end_page+1):
    sar=driver_3.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']/img")
    for j in sar:
        image=j.get_attribute('src')
        Jeans_Image.append(image)
        
    try:
        nxt_button=driver_3.find_element_by_xpath("//li[@class='a-last']/a").click()
    #driver_1.get(nxt_button[i].get_attribute('href'))
    except NoSuchElementException:

        time.sleep(15)

# %%
Jeans_Image
# Out:
# ['https://m.media-amazon.com/images/I/61Tb-wMh6kL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61chZyTCw9L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71FZrMK0swL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71rWwlHhQHL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71tofDe1MZL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/616xchp1ECL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51UlwkHPtmL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81GpX4leryL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61ZGXTSfA3L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61TwfPRLhrL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91mXH+SEo7L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/714EXTMcpuL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71jtjinnCLL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61UZtv8GRtL._AC_UL320_.jpg',
# ...

# %%
len(Jeans_Image)
# Out:
# 715

# %%
Sarees=[]
Sarees=Sarees_Image[0:376]
len(Sarees)
# Out:
# 376

# %%
Trousers=[]
Trousers=Trousers_Image[0:376]
len(Trousers)
# Out:
# 376

# %%
Jeans=[]
Jeans=Jeans_Image[0:376]
len(Jeans)
# Out:
# 376

# %% [markdown]
# ## Hence, we have 376 images in all three lists.

# %%
# Creating Directories
import os

def directory(dir):
    current_path=os.getcwd()
    new=os.path.join(current_path,dir)
    if not os.path.exists(new):
        os.makedirs(new)
        
directory('Sarees_Images')
directory('Trousers_Images')
directory('Jeans_Images')

# Dowloading images

import shutil
import requests

# %%
for index, link in enumerate(Sarees):
    print('Downloading {0} of 376 saree images'.format(index+1))
    response=requests.get(link)
    with open('Sarees_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
for index, link in enumerate(Trousers):
    print('Downloading {0} of 376 trouser images'.format(index+1))
    response=requests.get(link)
    with open('Trousers_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
for index, link in enumerate(Jeans):
    print('Downloading {0} of 376 jeans images'.format(index+1))
    response=requests.get(link)
    with open('Jeans_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
#closing the driver
driver_1.close()
driver_2.close()
driver_3.close()
